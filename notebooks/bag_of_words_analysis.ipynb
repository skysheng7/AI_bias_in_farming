# %% [markdown]
# # Bag of words analysis for GPT-4o generated text descriptions

# %%
import pandas as pd
from pathlib import Path

from AI_representation_bias_in_farming import module6_extract_pic_feature_words

# import the dataframe that records the 1 gram bag of words in all gpt-4o descriptions
gpt4o_description_file = Path("..") / "results" / "megadata" / "GPT4o_description_1_2gram_bag_of_words.csv"
gpt4o_description_1_2gram = pd.read_csv(gpt4o_description_file, header=0, low_memory=False)

# %% [markdown]
# ## Exploratory image analysis
# The goal of this analysis is to see which word or phrases (2 words) are the key features that would describe an image of extensive versus intensive farm

# %% [markdown]
# [1] playground to seeing what context does each word show up in

# %%
# filter out the rows that certains words of interest, and print out in what sentences does the word shwo up
temp = gpt4o_description_1_2gram[gpt4o_description_1_2gram["farm_type"] == "dairy"]
count = temp['GPT4o_description'].str.contains('pastures', case=False, na=False)
filtered_df = temp[count].reset_index(drop=True)
print(filtered_df["GPT4o_description"][0])
#filtered_df
# Out:
# The image depicts a vibrant, bustling farm scene. In the foreground, several cows are grazing in fenced pastures, with farmers tending to them. The cows are black and white, typical of dairy breeds, and are scattered across the lush green fields.
#
# There are multiple barns in the background, painted in red with white trim, and a central barn that is white with a gray roof. These barns are surrounded by various farming equipment, including tractors and hay bales. A large silo is positioned near the barns, indicating grain storage.
#
# The landscape extends into the distance with fields of crops and a river or stream running through the farmland. The sky is partly cloudy, suggesting a pleasant day. The overall scene is idyllic, capturing the essence of rural farm life with attention to detail in the activities and structures present.

# %%
# see how frequent certain words show up in certain generation_type
row = gpt4o_description_1_2gram[(gpt4o_description_1_2gram["generation_type"] == "basic") 
                                & (gpt4o_description_1_2gram["model"] == "dall-e-3") 
                                & (gpt4o_description_1_2gram["farm_type"] == "pig")]
stasitfy = row[(row["metal railings"]==1)]
#columns_with_ones = stasitfy.columns[stasitfy.iloc[0] == 1].tolist()
#columns_with_ones
stasitfy
# Out:
# Empty DataFrame
# Columns: [file, generation_type, country, farm_type, prompt, revised_prompt, model, size, quality, response_format, finish_reason, description_model, GPT4o_description, GPT4o_description_token_count, GPT4o_prompt, GPT4o_image_resolution, GPT4o_temperature, GPT4o_system_fingerprint, abundance, accents, access, accompanied, accompanied tall, active, active farm, active farming, actively, actively engaged, actively moving, actively working, activities, activities background, activities farm, activities feeding, activities tending, activity, activity background, activity farm, activity featuring, activity inside, activity people, add, add depth, adding, adding agricultural, adding classic, adding depth, adding dramatic, adding farm, adding idyllic, adding lively, adding natural, adding pastoral, adding peaceful, adding picturesque, adding rural, adding rustic, adding sense, adding serene, adding texture, adding touch, adding tranquil, adding variety, adding whimsical, additional, additional barns, additional cows, additional farm, additional illumination, additional red, adds, adjacent, adjacent barn, adjacent barns, adjacent farmhouse, adjacent house, adorned, adorned flower, adults, adults piglets, advanced, aesthetic, afternoon, afternoon casting, afternoon early, afternoon overall, age, agricultural, agricultural activities, agricultural activity, agricultural environment, agricultural operation, agricultural practices, agricultural setting, agriculture, agriculture nature, air, airy, airy atmosphere, aisle, ...]
# Index: []
#
# [0 rows x 4176 columns]

# %%
# see the key words in one specific image
row = gpt4o_description_1_2gram[gpt4o_description_1_2gram["file"] == "pig_farm_typical_country_no_revise_Australia_74.png"]
columns_with_ones = row.columns[row.iloc[0] == 1].tolist()

print(columns_with_ones)
# Out:
# ['adding', 'ambiance', 'area barn', 'areas', 'atmosphere overall', 'barn', 'barn corrugated', 'barn divided', 'casting', 'casting warm', 'composition', 'composition highlights', 'containing', 'containing pigs', 'corrugated', 'corrugated metal', 'creating', 'creating serene', 'depicts pig', 'divided', 'entire', 'farm sunrise', 'glow', 'glow entire', 'golden', 'highlights', 'inside', 'inside large', 'landscape', 'landscape trees', 'large', 'large open', 'lying', 'metal', 'metal roof', 'mud', 'muddy', 'natural', 'natural setting', 'open', 'open sided', 'overall composition', 'peaceful', 'peaceful atmosphere', 'pens', 'pens containing', 'pigs pigs', 'pigs standing', 'rain', 'recent', 'recent rain', 'reflects', 'rising', 'roof', 'rustic', 'scene set', 'serene', 'set', 'setting farm', 'sided', 'sided barn', 'standing', 'standing lying', 'streams', 'suggesting recent', 'sun', 'sun rising', 'sunlight', 'sunlight streams', 'sunrise', 'trees', 'trees creating', 'warm', 'warm glow', 'warm golden', 'watering']

# %% [markdown]
# [2] Exploratory : First list of interests
# - I'll put all the images that contains the word of interest in its GPT-4o description text into a seperate folder.
# - For example, all images that contain "grazing" will be placed into "results/cluster_eda/dairy/extensive/grazing"

# %%
# list of words associated with extensive dairy
dairy_extensive = ["grazing", "graze", "grass", "pasture", "pastures"]
dairy_intensive = ["automated", "ceiling", "interior", "machinery", "machine", "machines", 
                   "modern", "metal", "roofed", "metal railing", "metal railings", "large windows", 
                   "barn spacious"]
pig_extensive = ["mud", "muddy", "soil", "dirt", "outdoor", "rural", "green", "grazing", "pasture", 
                 "pastures", "graze", "grass", "straw"]
pig_intensive = ["floor", "automated", "ceiling", "interior", "machinery", "machine", "machines", 
                 "modern", "metal", "roofed", "metal railing", "metal railings", "large windows", 
                 "barn spacious"]

# %% [markdown]
# - Warning: the code cell below takes a long time to run (~ 30 minutes), please don't run again, as it's time and resource consuming.

# %%
# Set up base paths
model = "dall-e-3"
source_base = Path("..") / "results"
dest_base = Path("..") / "results" / "cluster_eda"

# Process dairy extensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "dairy",
    "extensive",
    dairy_extensive,
    source_base,
    dest_base,
    model,
    grouping_style="by word",
    negative_word_list=None
)

# Process dairy intensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "dairy",
    "intensive",
    dairy_intensive,
    source_base,
    dest_base,
    model,
    grouping_style="by word",
    negative_word_list=None
)

# Process pig extensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "pig",
    "extensive",
    pig_extensive,
    source_base,
    dest_base,
    model,
    grouping_style="by word",
    negative_word_list=None
)

# Process pig intensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "pig",
    "intensive",
    pig_intensive,
    source_base,
    dest_base,
    model,
    grouping_style="by word",
    negative_word_list=None
)

# %% [markdown]
# [2] Exploratory : Second list of interests (refined based on the first)
# - I'll put all the images that contains the word of interest in its GPT-4o description text into a seperate folder,
# AFTER deleting those images that contains words in the negative list.
# - For example, all images that contain "grazing", but does not contain ANY of the words in dairy_extensive_negative_list, will be placed into "results/cluster_eda2/dairy/extensive/grazing"

# %%
# dairy 
dairy_extensive = ["grazing", "graze", "pasture", "pastures"]
dairy_extensive_negative_list = ["ceiling", "metal railing", "metal railings", "barn spacious", "spacious barn", 
                                 "bars", "aisle", "illumination", "interior large", "large lit", "large indoor", 
                                 "spacious rows", "metal pens", "beams high", "barn rows", "barn lit"]
dairy_intensive = ["ceiling", "metal railing", "metal railings", "barn spacious", "spacious barn", 
                   "bars", "aisle", "illumination", "interior large", "large lit", "large indoor", "spacious rows", 
                   "metal pens", "beams high", "barn rows", "barn lit"]
dairy_intensive_negative_list = ["grazing", "graze", "pasture", "pastures"]

# pig
pig_extensive = ["grazing", "graze", "pasture", "pastures", "grass", "soil", "green", "mud", "muddy", 
                 "rural"]
pig_extensive_negative_list = ["ceiling", "ceilings", "metal railing", "metal railings", "barn spacious", "spacious barn", 
                               "bars", "aisle", "illumination", "interior large", "large lit", "indoor", 
                               "spacious rows", "metal pens", "beams high", "lighting bright", "barn rows", 
                               "narrow barn", "industrial", "barn lit", "concrete", "central walkway", 
                               "light streaming", "interior barn", "rows pens", "barn floor", "closely packed"]
pig_intensive = ["floor", "ceiling", "metal railing", "metal railings", "barn spacious", 
                 "spacious barn", "bars", "aisle", "illumination", "large lit", 
                 "indoor", "spacious rows", "metal pens", "typical modern", "barn lit", 
                 "concrete", "central walkway"]
pig_intensive_negative_list = ["grazing", "graze", "pasture", "pastures", "grass", "soil", "outdoor", 
                               "pastoral", "scattered landscape", "vegetation"]

# %% [markdown]
# - Warning: the code cell below takes a long time to run (~ 30 minutes), please don't run again, as it's time and resource consuming.

# %%
# Set up base paths
model = "dall-e-3"
source_base = Path("..") / "results"
dest_base = Path("..") / "results" / "cluster_eda3"

# Process dairy extensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "dairy",
    "pasture_or_mud",
    dairy_extensive,
    source_base,
    dest_base,
    model,
    grouping_style="combine",
    negative_word_list= dairy_extensive_negative_list
)

# Process dairy intensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "dairy",
    "indoor",
    dairy_intensive,
    source_base,
    dest_base,
    model,
    grouping_style="combine",
    negative_word_list= dairy_intensive_negative_list
)

# Process pig extensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "pig",
    "pasture_or_mud",
    pig_extensive,
    source_base,
    dest_base,
    model,
    grouping_style="combine",
    negative_word_list = pig_extensive_negative_list
)

# Process pig intensive
module6_extract_pic_feature_words.process_farm_images(
    gpt4o_description_1_2gram,
    "pig",
    "indoor",
    pig_intensive,
    source_base,
    dest_base,
    model,
    grouping_style="combine",
    negative_word_list = pig_intensive_negative_list
)

# %%
# summary
intensive_extensive_summary = (
    module6_extract_pic_feature_words.intensive_extensive_calculation(
        gpt4o_description_1_2gram,
        dairy_extensive,
        dairy_intensive,
        pig_extensive,
        pig_intensive,
        dairy_extensive_negative_list,
        dairy_intensive_negative_list,
        pig_extensive_negative_list,
        pig_intensive_negative_list
    )
)
intensive_extensive_summary
# Out:
#               generation_type            country farm_type  \
# 0                       basic                NaN     dairy
# 1                       basic                NaN       pig
# 2             basic_no_revise                NaN     dairy
# 3             basic_no_revise                NaN       pig
# 4                     typical                NaN     dairy
# ..                        ...                ...       ...
# 91  typical_country_no_revise            Germany     dairy
# 92  typical_country_no_revise        New Zealand     dairy
# 93  typical_country_no_revise  the United States       pig
# 94  typical_country_no_revise              Spain       pig
# 95  typical_country_no_revise          Australia       pig
#
#                                                prompt        model  \
# 0                                       A dairy farm.     dall-e-3
# 1                                         A pig farm.     dall-e-3
# 2   A dairy farm.I NEED to test how the tool works...     dall-e-3
# 3   A pig farm.I NEED to test how the tool works w...     dall-e-3
# 4                               A typical dairy farm.     dall-e-3
# ..                                                ...          ...
# 91  A typical dairy farm in Germany.I NEED to test...  sd3.5-large
# 92  A typical dairy farm in New Zealand.I NEED to ...  sd3.5-large
# 93  A typical pig farm in the United States.I NEED...  sd3.5-large
# 94  A typical pig farm in Spain.I NEED to test how...  sd3.5-large
# 95  A typical pig farm in Australia.I NEED to test...  sd3.5-large
#
#     total_rows  inten_sum  exten_sum  inten_pct  exten_pct
# 0          100          0         95       0.00       0.95
# 1          100          0         96       0.00       0.96
# 2          100         47         24       0.47       0.24
# 3          100         90          0       0.90       0.00
# 4          100          0         99       0.00       0.99
# ..         ...        ...        ...        ...        ...
# 91          10          0          8       0.00       0.80
# 92          10          0         10       0.00       1.00
# 93          10          0          9       0.00       0.90
# 94          10          1          4       0.10       0.40
# 95          10          0          6       0.00       0.60
#
# [96 rows x 10 columns]

# %%
interest = intensive_extensive_summary[(intensive_extensive_summary["farm_type"] == "pig") 
                                       & (intensive_extensive_summary["model"] == "dall-e-3")]
#interest

# %%
output_path = Path("..") / "results" / "plots" / "intensive_extensive_summary.png"
fig = module6_extract_pic_feature_words.save_plot_grid(intensive_extensive_summary, output_path)
fig
