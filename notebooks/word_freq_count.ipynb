# %% [markdown]
# # Bag of words for metadata of the generated images

# %%
import pandas as pd
from pathlib import Path

from AI_representation_bias_in_farming import module4_word_freq_count

# %%
# import the megadata dataframe, and sort by the length of revised prompts
megadata_file = Path("..") / "results" / "megadata" / "image_megadata.csv"
megadata = pd.read_csv(megadata_file, header=0)

# %%
megadata
# Out:
#                                                    file  \
# 0                                dairy_farm_basic_1.png
# 1                                dairy_farm_basic_2.png
# 2                                dairy_farm_basic_3.png
# 3                                dairy_farm_basic_4.png
# 4                                dairy_farm_basic_5.png
# ...                                                 ...
# 5275  pig_farm_typical_country_no_revise_Australia_1...
# 5276  pig_farm_typical_country_no_revise_Australia_1...
# 5277  pig_farm_typical_country_no_revise_Australia_1...
# 5278  pig_farm_typical_country_no_revise_Australia_1...
# 5279  pig_farm_typical_country_no_revise_Australia_1...
#
#                 generation_type    country farm_type  \
# 0                         basic        NaN     dairy
# 1                         basic        NaN     dairy
# 2                         basic        NaN     dairy
# 3                         basic        NaN     dairy
# 4                         basic        NaN     dairy
# ...                         ...        ...       ...
# 5275  typical_country_no_revise  Australia       pig
# 5276  typical_country_no_revise  Australia       pig
# 5277  typical_country_no_revise  Australia       pig
# 5278  typical_country_no_revise  Australia       pig
# 5279  typical_country_no_revise  Australia       pig
#
#                                                  prompt  \
# 0                                         A dairy farm.
# 1                                         A dairy farm.
# 2                                         A dairy farm.
# 3                                         A dairy farm.
# 4                                         A dairy farm.
# ...                                                 ...
# 5275  A typical pig farm in Australia.I NEED to test...
# 5276  A typical pig farm in Australia.I NEED to test...
# 5277  A typical pig farm in Australia.I NEED to test...
# 5278  A typical pig farm in Australia.I NEED to test...
# 5279  A typical pig farm in Australia.I NEED to test...
#
#                                          revised_prompt        model  \
# 0     Visualize a sprawling dairy farm on a sunny da...     dall-e-3
# 1     Picture a serene rural landscape under a clear...     dall-e-3
# 2     Imagine a peaceful outdoor scene of a dairy fa...     dall-e-3
# 3     An image capturing the day-to-day activities o...     dall-e-3
# 4     Imagine an engaging scene of a dairy farm. Pas...     dall-e-3
# ...                                                 ...          ...
# 5275                                                NaN  sd3.5-large
# 5276                                                NaN  sd3.5-large
# 5277                                                NaN  sd3.5-large
# 5278                                                NaN  sd3.5-large
# 5279                                                NaN  sd3.5-large
#
#            size   quality response_format finish_reason  description_model  \
# 0     1024x1024  standard        b64_json           NaN  gpt-4o-2024-08-06
# 1     1024x1024  standard        b64_json           NaN  gpt-4o-2024-08-06
# 2     1024x1024  standard        b64_json           NaN  gpt-4o-2024-08-06
# 3     1024x1024  standard        b64_json           NaN  gpt-4o-2024-08-06
# 4     1024x1024  standard        b64_json           NaN  gpt-4o-2024-08-06
# ...         ...       ...             ...           ...                ...
# 5275  1024x1024  standard           bytes       SUCCESS  gpt-4o-2024-08-06
# 5276  1024x1024  standard           bytes       SUCCESS  gpt-4o-2024-08-06
# 5277  1024x1024  standard           bytes       SUCCESS  gpt-4o-2024-08-06
# 5278  1024x1024  standard           bytes       SUCCESS  gpt-4o-2024-08-06
# 5279  1024x1024  standard           bytes       SUCCESS  gpt-4o-2024-08-06
#
#                                       GPT4o_description  \
# 0     The image depicts a vibrant and idyllic farm s...
# 1     The image depicts a vibrant, bustling farm sce...
# 2     The image depicts a picturesque rural farm sce...
# 3     The image depicts a picturesque farm scene at ...
# 4     The image depicts a picturesque farm scene wit...
# ...                                                 ...
# 5275  The image features three adorable piglets stan...
# 5276  The image shows a group of young pigs in a bar...
# 5277  The image shows a group of young pigs standing...
# 5278  The image depicts a pastoral scene with severa...
# 5279  The image shows a group of piglets in a grassy...
#
#       GPT4o_description_token_count                   GPT4o_prompt  \
# 0                             210.0  Describe the image in detail.
# 1                             162.0  Describe the image in detail.
# 2                             174.0  Describe the image in detail.
# 3                             162.0  Describe the image in detail.
# 4                             191.0  Describe the image in detail.
# ...                             ...                            ...
# 5275                          101.0  Describe the image in detail.
# 5276                          120.0  Describe the image in detail.
# 5277                          113.0  Describe the image in detail.
# 5278                          120.0  Describe the image in detail.
# 5279                          104.0  Describe the image in detail.
#
#      GPT4o_image_resolution  GPT4o_temperature GPT4o_system_fingerprint
# 0                      high                0.2            fp_45cf54deae
# 1                      high                0.2            fp_45cf54deae
# 2                      high                0.2            fp_45cf54deae
# 3                      high                0.2            fp_45cf54deae
# 4                      high                0.2            fp_45cf54deae
# ...                     ...                ...                      ...
# 5275                   high                0.2            fp_45cf54deae
# 5276                   high                0.2            fp_45cf54deae
# 5277                   high                0.2            fp_45cf54deae
# 5278                   high                0.2            fp_45cf54deae
# 5279                   high                0.2            fp_45cf54deae
#
# [5280 rows x 18 columns]
